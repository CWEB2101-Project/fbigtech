# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x1921a956d68>,
#   <matplotlib.axis.XTick at 0x1921a9566d8>,
#   <matplotlib.axis.XTick at 0x1921a956320>,
#   <matplotlib.axis.XTick at 0x1921ca01d68>,
#   <matplotlib.axis.XTick at 0x1921ca10278>,
#   <matplotlib.axis.XTick at 0x1921ca101d0>,
#   <matplotlib.axis.XTick at 0x1921ca109e8>,
#   <matplotlib.axis.XTick at 0x1921ca10ef0>,
#   <matplotlib.axis.XTick at 0x1921ca18438>,
#   <matplotlib.axis.XTick at 0x1921ca18940>,
#   <matplotlib.axis.XTick at 0x1921ca18e48>,
#   <matplotlib.axis.XTick at 0x1921ca1e390>,
#   <matplotlib.axis.XTick at 0x1921ca1e898>,
#   <matplotlib.axis.XTick at 0x1921ca1eda0>,
#   <matplotlib.axis.XTick at 0x1921ca1e978>,
#   <matplotlib.axis.XTick at 0x1921ca18390>,
#   <matplotlib.axis.XTick at 0x1921ca26208>,
#   <matplotlib.axis.XTick at 0x1921ca266a0>,
#   <matplotlib.axis.XTick at 0x1921ca26ba8>,
#   <matplotlib.axis.XTick at 0x1921ca30160>,
#   <matplotlib.axis.XTick at 0x1921ca305f8>,
#   <matplotlib.axis.XTick at 0x1921ca30b00>,
#   <matplotlib.axis.XTick at 0x1921ca380b8>,
#   <matplotlib.axis.XTick at 0x1921ca30550>,
#   <matplotlib.axis.XTick at 0x1921ca26a20>,
#   <matplotlib.axis.XTick at 0x1921ca38550>,
#   <matplotlib.axis.XTick at 0x1921ca38908>,
#   <matplotlib.axis.XTick at 0x1921ca38e10>,
#   <matplotlib.axis.XTick at 0x1921ca40358>,
#   <matplotlib.axis.XTick at 0x1921ca40860>,
#   <matplotlib.axis.XTick at 0x1921ca40d68>,
#   <matplotlib.axis.XTick at 0x1921ca492b0>,
#   <matplotlib.axis.XTick at 0x1921ca40828>,
#   <matplotlib.axis.XTick at 0x1921ca38dd8>,
#   <matplotlib.axis.XTick at 0x1921ca26eb8>,
#   <matplotlib.axis.XTick at 0x1921ca49278>,
#   <matplotlib.axis.XTick at 0x1921ca49f28>,
#   <matplotlib.axis.XTick at 0x1921ca50470>,
#   <matplotlib.axis.XTick at 0x1921ca50978>,
#   <matplotlib.axis.XTick at 0x1921ca50e80>,
#   <matplotlib.axis.XTick at 0x1921ca593c8>,
#   <matplotlib.axis.XTick at 0x1921ca598d0>,
#   <matplotlib.axis.XTick at 0x1921ca50518>,
#   <matplotlib.axis.XTick at 0x1921ca38630>,
#   <matplotlib.axis.XTick at 0x1921ca59c18>,
#   <matplotlib.axis.XTick at 0x1921ca62198>,
#   <matplotlib.axis.XTick at 0x1921ca62668>,
#   <matplotlib.axis.XTick at 0x1921ca62b70>,
#   <matplotlib.axis.XTick at 0x1921ca69128>,
#   <matplotlib.axis.XTick at 0x1921ca695c0>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0,0.5,'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()
